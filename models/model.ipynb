# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import torch
from torch import nn
from torch import optim
from torch.utils.data import Dataset, DataLoader
import torch.nn.functional as F
from tqdm import tqdm
import torchutils as tu
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.preprocessing import StandardScaler
torch.manual_seed(666)
import faiss

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"

# %%
df = pd.read_csv("~/DS_Elbrus/123/game_data.csv")

# %%
from transformers import AutoTokenizer, AutoModel

tokenizer = AutoTokenizer.from_pretrained("cointegrated/rubert-tiny2")
model = AutoModel.from_pretrained("cointegrated/rubert-tiny2")

# %%
def embed_bert_cls(text, model, tokenizer):
    tokens = tokenizer.encode(text, add_special_tokens=True)
    with torch.no_grad():
        outputs = model(torch.tensor([tokens]))
    embeddings = outputs.last_hidden_state[:, 0, :]
    embeddings = torch.nn.functional.normalize(embeddings)
    return embeddings[0].cpu().numpy()

print(embed_bert_cls("Hello, world", model, tokenizer).shape)
# Out:
# (312,)

# %%
df
# Out:
#                               title  \
# 0                         Wasteland
# 1                The Need for Speed
# 2                      System Shock
# 3           Warcraft: Orcs & Humans
# 4     Warcraft 2: Tides of Darkness
# ...                             ...
# 1956               State of Decay 3
# 1957            The Elder Scrolls 6
# 1958                  Mass Effect 5
# 1959          Marvel’s Spider-Man 3
# 1960                 Marvel’s X-Men
#
#                                               image_url  \
# 0     https://iwant.games/wp-content/uploads/wastela...
# 1     https://iwant.games/wp-content/uploads/the-nee...
# 2     https://iwant.games/wp-content/uploads/system-...
# 3     https://iwant.games/wp-content/uploads/warcraf...
# 4     https://iwant.games/wp-content/uploads/warcraf...
# ...                                                 ...
# 1956  https://iwant.games/wp-content/uploads/state-o...
# 1957  https://iwant.games/wp-content/uploads/the-eld...
# 1958  https://iwant.games/wp-content/uploads/mass-ef...
# 1959  https://iwant.games/wp-content/uploads/marvels...
# 1960  https://iwant.games/wp-content/uploads/marvels...
#
#                                                page_url  \
# 0                        https://iwant.games/wasteland/
# 1               https://iwant.games/the-need-for-speed/
# 2                     https://iwant.games/system-shock/
# 3         https://iwant.games/warcraft-orcs-and-humans/
# 4     https://iwant.games/warcraft-2-tides-of-darkness/
# ...                                                 ...
# 1956              https://iwant.games/state-of-decay-3/
# 1957           https://iwant.games/the-elder-scrolls-6/
# 1958                 https://iwant.games/mass-effect-5/
# 1959          https://iwant.games/marvels-spider-man-3/
# 1960                 https://iwant.games/marvels-x-men/
#
#                                             description
# 0     Wasteland (рус. «Пустошь») — это одиночная, ро...
# 1     Road & Track Presents: The Need for Speed (рус...
# 2     System Shock – хоррор на выживание в жанре нау...
# 3     Warcraft: Orcs and Humans — стратегия в реальн...
# 4     Warcraft 2: Tides of Darkness — стратегия в ре...
# ...                                                 ...
# 1956  State of Decay 3 — постапокалиптический экшен ...
# 1957  The Elder Scrolls 6 — шестая часть популярной ...
# 1958  Mass Effect 5 — научно-фантастическая Action/R...
# 1959  Marvel's Spider-Man 3 — приключенческий экшен ...
# 1960  Marvel's X-Men — приключенческий экшен от 3-го...
#
# [1961 rows x 4 columns]

# %%
# Создание эмбеддингов для описаний
description_embeddings = np.vstack(
    df["description"].apply(lambda x: embed_bert_cls(x, model, tokenizer)).values
)

# %%
# Построение индекса FAISS
index = faiss.IndexFlatL2(description_embeddings.shape[1])
index.add(description_embeddings.astype(np.float32))

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1961 entries, 0 to 1960
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   title        1961 non-null   object
#  1   image_url    1961 non-null   object
#  2   page_url     1961 non-null   object
#  3   description  1961 non-null   object
# dtypes: object(4)
# memory usage: 61.4+ KB

# %%
def find_shows(query, df, model, tokenizer, index, top_k=int):
    # Создание эмбеддингов для запроса
    query_embedding = embed_bert_cls(query, model, tokenizer).reshape(1, -1)

    # Поиск топ-K ближайших соседей с использованием Faiss
    _, top_k_indices = index.search(query_embedding.astype(np.float32), top_k)

    # Извлечение соответствующих строк из DataFrame
    result = df.iloc[top_k_indices[0]].copy()

    # Вычисление косинусного сходства для сортировки (опционально)
    similarities = cosine_similarity(
        query_embedding, description_embeddings[top_k_indices[0]]
    ).flatten()
    result["similarity"] = similarities

    return result.sort_values("similarity", ascending=False)

# %%
query = "Шутер от 1 лица"
find_shows(query, df, model, tokenizer, index, 10)
# Out:
#                                  title  \
# 616                           Get Even
# 1846                      Son and Bone
# 813                    Generation Zero
# 595            Sniper: Ghost Warrior 3
# 476                        The Witness
# 723                              Agony
# 688          Kingdom Come: Deliverance
# 856            Wolfenstein: Youngblood
# 573        theHunter: Call of the Wild
# 1765  Sniper Ghost Warrior Contracts 3
#
#                                               image_url  \
# 616   https://iwant.games/wp-content/uploads/Get-Eve...
# 1846  https://iwant.games/wp-content/uploads/son-and...
# 813   https://iwant.games/wp-content/uploads/generat...
# 595   https://iwant.games/wp-content/uploads/sniper-...
# 476   https://iwant.games/wp-content/uploads/the-wit...
# 723   https://iwant.games/wp-content/uploads/agony-l...
# 688   https://iwant.games/wp-content/uploads/kingdom...
# 856   https://iwant.games/wp-content/uploads/wolfens...
# 573   https://iwant.games/wp-content/uploads/thehunt...
# 1765  https://iwant.games/wp-content/uploads/sniper-...
#
#                                                page_url  \
# 616                       https://iwant.games/get-even/
# 1846                  https://iwant.games/son-and-bone/
# 813                https://iwant.games/generation-zero/
# 595         https://iwant.games/sniper-ghost-warrior-3/
# 476                    https://iwant.games/the-witness/
# 723                          https://iwant.games/agony/
# 688       https://iwant.games/kingdom-come-deliverance/
# 856         https://iwant.games/wolfenstein-youngblood/
# 573     https://iwant.games/thehunter-call-of-the-wild/
# 1765  https://iwant.games/sniper-ghost-warrior-contr...
#
#                                             description  similarity
# 616   Шутер от 1-го лица, события которого происходя...    0.670842
# 1846  Son and Bone — шутер от 1-го лица во вселенной...    0.668715
# 813   Generation Zero (рус. «Поколение Нулевых») - к...    0.666123
# 595   Sniper: Ghost Warrior 3 - тактический шутер от...    0.653031
# 476   The Witness - 3D видеоигра от 1-го лица голово...    0.628125
# 723   Agony («Агония») - одиночная игра от 1-го лица...    0.617910
# 688   Kingdom Come: Deliverance - средневековые сраж...    0.605801
# 856   Wolfenstein Youngblood («Молодая кровь») - коо...    0.603804
# 573   TheHunter: Call of the Wild - охотничий симуля...    0.601489
# 1765  Sniper Ghost Warrior Contracts 3 — третья част...    0.601481

# %%
from transformers import AutoModel, AutoTokenizer

model = AutoModel.from_pretrained("cointegrated/rubert-tiny2")
tokenizer = AutoTokenizer.from_pretrained("cointegrated/rubert-tiny2")

# Сохранение модели и токенизатора
model.save_pretrained("my_saved_model")
tokenizer.save_pretrained("my_saved_model")
# Out:
# /home/ubuntu-pc/miniforge3/envs/Math/lib/python3.11/site-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# ('my_saved_model/tokenizer_config.json',
#  'my_saved_model/special_tokens_map.json',
#  'my_saved_model/vocab.txt',
#  'my_saved_model/added_tokens.json',
#  'my_saved_model/tokenizer.json')
